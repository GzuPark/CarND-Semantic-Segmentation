# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loss = pd.read_table('log_loss', header=None)

# %%
sns.set(color_codes=True)
plt.plot(loss)
plt.ylim(0, 1)
plt.savefig('assets/log_loss.png')
